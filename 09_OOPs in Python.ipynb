# %% [markdown]
# ### init method

# %%
class Person:
   def __init__(self, fname):
       self.name = fname

   def say_hi(self):
       print('Hello, my name is', self.name)

# %%
p = Person('John')
p.say_hi()
# Out:
# Hello, my name is John

# %%
q = Person('Aarti')
q.say_hi()
# Out:
# Hello, my name is Aarti

# %% [markdown]
# ###  Classes: Grouping data

# %%
class Time:
    def __init__(self):
        self.hours = 0
        self.minutes = 0

    def print_time(self):
        print('Hours:', self.hours, end=' ')
        print('Minutes:', self.minutes)
        print( 'Minutes:', self. minutes )

# %%
my_time = Time()
my_time.print_time()
# Out:
# Hours: 0 Minutes: 0
# Minutes: 0

# %%
my_time.hours = 10
my_time.minutes = 30

# %%
print(f'Hours: {my_time.hours} Minutes: {my_time.minutes}')
# Out:
# Hours: 10 Minutes: 30

# %%
time_2 = Time()
time_2.hours = 5
time_2.minutes = 45

# %%
print('Updated time:')
print(f'end=Hours: {time_2.hours} Minutes: {time_2.minutes}')
# Out:
# Updated time:
# end=Hours: 5 Minutes: 45

# %% [markdown]
# ###  Instance methods

# %%
class Time():
    def __init__(self):
        self.hours = 0
        self.minutes = 0

    def print_time(self):
        print('Hours:', self.hours, end=' ')
        print('Minutes:', self.minutes)

# %%
time1 = Time()
time1.hours = 4
time1.minutes = 5
time1.print_time()
# Out:
# Hours: 4 Minutes: 5

# %% [markdown]
# #### Accidentally forgetting the self parameter of a method generates an error when calling the method

# %%
class Employee:
    def __init__(self):
        self.wage = 0
        self.hours_worked = 0

    def calculate_pay():  # programmer forget to include self as a parameter
        return self.wage * self.hours_worked

alice = Employee()
alice.age = 22
alice.wage = 15
alice.hours_worked = 40 
print('Alice pay:', alice.calculate_pay())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 13
#      11 alice.wage = 15
#      12 alice.hours_worked = 40
# ---> 13 print('Alice pay:', alice.calculate_pay())
#
# TypeError: Employee.calculate_pay() takes 0 positional arguments but 1 was given

# %% [markdown]
# ### Class constructors

# %% [markdown]
# #### Adding parameters to a constructor

# %%
class RaceTime:
    def __init__(self, start_hrs, start_mins, end_hrs, end_mins, dist):
        self.start_hrs = start_hrs
        self.start_mins = start_mins
        self.end_hrs = end_hrs
        self.end_mins = end_mins
        self.distance = dist

    def print_time(self):
        if self.end_mins >= self.start_mins:
            minutes = self.end_mins - self.start_mins
            hours = self.end_hrs - self.start_hrs
        else:
            minutes = 60 - self.start_mins + self.end_mins
            hours = self.end_hrs - self.start_hrs - 1
        print(f'Time to complete race: {hours}:{minutes}')

    def print_pace(self):
        if self.end_mins >= self.start_mins:
            minutes = self.end_mins - self.start_mins
            hours = self.end_hrs - self.start_hrs
        else:
            minutes = 60 - self.start_mins + self.end_mins
            hours = self.end_hrs - self.start_hrs - 1
        print(f'Time to complete race: {hours}:{minutes}')

    def print_pace(self):
        if self.end_mins >= self.start_mins:
            minutes = self.end_mins - self.start_mins
            hours = self.end_hrs - self.start_hrs
        else:
            minutes = 60 - self.start_mins + self.end_mins
            hours = self.end_hrs - self.start_hrs - 1

            total_minutes = hours * 60 + minutes
            print(f'Time to complete race: {hours}:{minutes}')

# %%
race_time = RaceTime(start_hours, start_minutes, end_hours, end_minutes, distance)

race_time.print_time()
race_time.print_pace()

# %% [markdown]
# ### Class and instance object types

# %% [markdown]
# ##### class attribute

# %%
class MarathonRunner :
    race_distance = 42.195   # Marathon distance in Kilometers
    def __init__(self):
        pass
    def get_speed(self):
        pass
runner1 = MarathonRunner()
runner2 = MarathonRunner()

# Marathon distance in Kilometers
print (MarathonRunner.race_distance)  # Look in c Lass namespace
print (runner1.race_distance)   # Look in instance namespace
print (runner2.race_distance)
# Out:
# 42.195
# 42.195
# 42.195

# %% [markdown]
# #### Instance attribute

# %%
class MarathonRunner :
    race_distance = 42.195   # Marathon distance in Kilometers
    def __init__(self):
        self.speed = 0
        # ...

    def get_speed(self):
        return self.speed

runner1 = MarathonRunner()
runner1.speed = 7.5
print('Runner 1 speed:' , runner1.get_speed())
# Out:
# Runner 1 speed: 7.5

# %%
runner2 = MarathonRunner()
runner2.speed = 8.0
print('Runner 2 speed:' , runner2.get_speed())
# Out:
# Runner 2 speed: 8.0
