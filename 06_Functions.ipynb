# %% [markdown]
# ## FUNCTION

# %%
def calc_pizza_area():
    pi_val = 3.14159265

    pizza_diameter = 12.0
    pizza_radius = pizza_diameter / 2.0
    pizza_area = pi_val * pizza_radius * pizza_radius
    return pizza_area

print('12.0 inch pizza is', calc_pizza_area(), 'square inches.')
# Out:
# 12.0 inch pizza is 113.09733540000002 square inches.

# %%
def  compute_square(num_to_square):
    return num_to_square * num_to_square

num_squared = compute_square(9)
print( '9 squared is ', num_squared)
# Out:
# 9 squared is  81

# %%
def calc_pizza_volume(pizza_diameter, pizza_height):
    pi_val = 3.14159265
    pizza_radius = pizza_diameter / 2.0
    pizza_area = pi_val * pizza_radius * pizza_radius
    pizza_volume = pizza_area * pizza_height
    return pizza_volume

# %%
print('12.0 x 0.8 inch pizza is', calc_pizza_volume(12.0, 0.8), 'cubic inches.')
# Out:
# 12.0 x 0.8 inch pizza is 90.47786832000003 cubic inches.

# %%
print('12.0 x 0.8 inch pizza is', calc_pizza_volume(7, 0.3), 'cubic inches.')
# Out:
# 12.0 x 0.8 inch pizza is 11.545352988750002 cubic inches.

# %%
print('12.0 x 0.8 inch pizza is', calc_pizza_volume(16.0, 0.8), 'cubic inches.')
# Out:
# 12.0 x 0.8 inch pizza is 160.84954368 cubic inches.

# %% [markdown]
# ### Print functions

# %%
def print_summary(oid,items,price):
    print( 'Order' ,oid)
    print( '    Items', items)
    print( '        Total:', price)

# %%
oid = 67
items = 5
price = 13.99
print_summary(oid,items,price)
# Out:
# Order 67
#     Items 5
#         Total: 13.99

# %%
def print_menu():
    print("Today's Menu:")
    print(' 1) Ice cream')
    print(' 2) Ginger Rasam')
    print(' 3) Quit\n')

quit_program = False

while not quit_program:
    print_menu()
    choice = int(input('Enter choice: '))
    if choice == 3 :
        print('Goodbye')
        quit_program = True
    else:
        print('Order: ', end='')
        if choice == 1 :
            print('Ice cream')
        elif choice == 2:
            print('Ginger Rasam')
        print()
# Out:
# Today's Menu:
#  1) Ice cream
#  2) Ginger Rasam
#  3) Quit
#
# Order: Ice cream
#
# Today's Menu:
#  1) Ice cream
#  2) Ginger Rasam
#  3) Quit
#
# Order: Ginger Rasam
#
# Today's Menu:
#  1) Ice cream
#  2) Ginger Rasam
#  3) Quit
#
# Goodbye

# %% [markdown]
# ### Dynamic typing

# %%
def add(x,y):
    return x + y

# %%
# passing integer as an argument
# sum of two integers
m = add(2,5)
print(m)
# Out:
# 7

# %%
# passing string as an argument
# concatenation Of two string
n = add('Aarti ' ,'Hadge')
print(n)
# Out:
# Aarti Hadge

# %%
# passing list as an argument
n = add([1,2,43],[67,8,98])
print(n)
# Out:
# [1, 2, 43, 67, 8, 98]

# %%
# passing dict as an argument
n = add({1:AARTI,2:SAGAR},{3:AMISHA,4:VANSHIKA})
print(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # passing dict as an argument
# ----> 2 n = add({1:AARTI,2:SAGAR},{3:AMISHA,4:VANSHIKA})
#       3 print(n)
#
# NameError: name 'AARTI' is not defined

# %% [markdown]
# ### Reasons for Functions

# %% [markdown]
# ##### Improving program readability

# %%
feet_per_step = 3
steps_per_minute = 70.0
calories_per_minute_walking = 3.5

steps = int(input('Enter number of steps walked: '))
print('Steps:', steps)

feet = steps * feet_per_step
print('Feet:', feet)
# Out:
# Steps: 27
# Feet: 81

# %%
minutes = steps / steps_per_minute
calories = minutes * calories_per_minute_walking
print('Calories:', calories)
# Out:
# Calories: 2.25

# %% [markdown]
# #### Modular program development

# %%
pi_val = 3.14
pizza_diameter_1 = 12.0
circle_radius_1 = pizza_diameter_1/2.0
circle_area_1 = pi_val * circle_radius_1 * circle_radius_1

pizza_diameter_2 = 14.0
circle_radius_2 = pizza_diameter_2/2.0
circle_area_2 = pi_val * circle_radius_2 * circle_radius_2

total_pizza_area = circle_area_1 + circle_area_2

print('A 12 and 14 inch pizza has', end=' ')
print(f' {total_pizza_area:,.2f} ' , end='')
print( 'square inches combined.')
# Out:
# A 12 and 14 inch pizza has  266.90 square inches combined.

# %%
def steps_to_feet(num_steps):
    feet_per_step = 3
    feet = num_steps * feet_per_step
    return feet

def steps_to_calories(num_steps):
    steps_per_minute = 70.0
    calories_per_minute_walking = 3.5
    minutes = num_steps/steps_per_minute
    calories = minutes*calories_per_minute_walking
    return calories

# %%
steps = int(input('Enter number of steps walked: '))
print('Steps:', steps)

feet = steps_to_feet(steps)
print('Feet: ', feet)
# Out:
# Steps: 45
# Feet:  135

# %%
steps = int(input('Enter number of steps walked: '))
print('Steps:', steps)

calories = steps_to_calories(steps)
print('Calories: ', calories)
# Out:
# Steps: 67
# Calories:  3.35

# %%
def steps_to_feet(num_steps) :
    feet_per_step = 3
    feet = num_steps * feet_per_step
    return feet

def steps_to_calories(num_steps):
    calories_per_step = 2
    calories = num_steps * calories_per_step
    return calories

steps = int(input('Enter number of steps walked: '))

feet = steps_to_feet(steps)
print('Feet:', feet)
calories = steps_to_calories(steps)
print('Calories:', calories)
# Out:
# Feet: 168
# Calories: 112

# %%
def calc_circle_area(circle_diameter):
    pi_val = 3.14
    circle_radius = circle_diameter / 2.0
    circle_area = pi_val * circle_radius * circle_radius
    return circle_area

pizza_diameter_1 = 12.0
pizza_diameter_2 = 14.0

total_pizza_area = calc_circle_area(pizza_diameter_1)+calc_circle_area(pizza_diameter_2)

print('A 12 and 14 inch pizza has', end=' ')
print(f'{total_pizza_area:.2f}', end=' ')
print('square inches combined.')
# Out:
# A 12 and 14 inch pizza has 266.90 square inches combined.

# %% [markdown]
# ### Mathematical functions

# %%
CM_PER_INCH = 2.54
INCHES_PER_FOOT = 12
print('CM_PER_INCH:', CM_PER_INCH)
print('INCHES_PER_FOOT:', INCHES_PER_FOOT)

def height_US_to_cm(feet, inches) :
    " " "Converts height in feet/ inches to centimeters" " "
    total_inches = feet*INCHES_PER_FOOT + inches
    cm = total_inches * CM_PER_INCH
    return cm

i_feet = 6
i_inches = 4

centimeters = height_US_to_cm(i_feet,i_inches)
print('Centimeters : ' , centimeters)
# Out:
# CM_PER_INCH: 2.54
# INCHES_PER_FOOT: 12
# Centimeters :  193.04

# %%
def compute_square(num_to_square):
    return num_to_square * num_to_square

c2 = compute_square(7) + compute_square(9)
print('7 squared plus 9 squared is', c2)
# Out:
# 7 squared plus 9 squared is 130

# %% [markdown]
# ### Modular functions for mathematical expressions

# %%
import math

def calc_circular_base_area(radius):
    return math.pi * radius * radius

def calc_cylinder_volume(baseRadius, height):
    return calc_circular_base_area(baseRadius) * height

def calc_cylinder_surface_area(baseRadius, height):
    return (2 * math.pi * baseRadius * height) + (2 * calc_circular_base_area(baseRadius))

radius = float(input('Enter base radius:'))
print(radius)
height = float(input ('Enter height:'))
print(height)

print( 'Cylinder volume: ' + f' {calc_cylinder_volume(radius,height):.3f}')

print( 'Cylinder surface area:' + f'{calc_cylinder_surface_area(radius,height):.3f}')
# Out:
# 56.0
# 7.0
# Cylinder volume:  68964.242
# Cylinder surface area:22167.078

# %% [markdown]
# ### Function Stub

# %%
def steps_to_feet(num_steps) :
    feet_per_step = 3
    feet = num_steps * feet_per_step
    return feet

def steps_to_calories(num_steps):
    pass

steps = int(input('Enter number of steps walked: '))
print('Steps:', steps)

feet = steps_to_feet(steps)
print('Feet:', feet)
calories = steps_to_calories(steps)
print('Calories:', calories)
# Out:
# Steps: 34
# Feet: 102
# Calories: None

# %%
def steps_to_feet(num_steps) :
    feet_per_step = 3
    feet = num_steps * feet_per_step
    return feet

def steps_to_calories(num_steps):
    print('FIXME: Finish step_to_calories() function')
    return -1

steps = int(input('Enter number of steps walked: '))
print('Steps:', steps)

feet = steps_to_feet(steps)
print('Feet:', feet)
calories = steps_to_calories(steps)
print('Calories:', calories)
# Out:
# Steps: 34
# Feet: 102
# FIXME: Finish step_to_calories() function
# Calories: -1

# %% [markdown]
# ### Functions with branches/loops

# %%
def calc_ebay_fee(sell_price):
  p50 =  0.13  #for amount $50 and lower
  p50_to_1000 = 0.05 # for $50.01-$1000
  p1000 = 0.02  # for $ 1000.01 and h igher
  fee = 0.50 # fee to List item

  if sell_price <= 50:
    fee = fee + (sell_price*p50)
    print('fee:', fee)
  elif sell_price <= 1000:
    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)
    print('fee:', fee)
  else:
    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\
            + ((sell_price-1000)*p1000)
    print('fee:', fee)
  return fee

selling_price = float(input('Enter item selling price (ex: 65.00):'))
print('eBay fee: $', calc_ebay_fee(selling_price))
# Out:
# fee: 27.3
# eBay fee: $ 27.3

# %% [markdown]
# ### Functions are objects

# %%
def print_human_head():
    print('  ||||| ')
    print('  ㅇ  ㅇ')
    print('    >')
    print('  ㅇㅇㅇㅇㅇ ')
    return

# %%
def print_monkey_head():
    print(' .-"-.')
    print('_/.-.-.\\_')
    print('( (oo) )')
    print(' |/\\|')
    print(' \\ .-. /')
    print('/`"""`\\')
    return

# %%
def print_figure(face):
    face() # Print the face
    print('   |')
    print(' --|--')
    print(' / | \\')
    print('@  |    @')
    print('   |')
    print(' / | \\')
    print(' @   @')
    return

# %%
choice = int(input('Enter "1" to draw monkey, "2" for human:'))

if choice ==1:
    print_figure(print_monkey_head)
elif choice == 2:
    print_figure(print_human_head)
# Out:
#  .-"-.
# _/.-.-.\_
# ( (oo) )
#  |/\|
#  \ .-. /
# /`"""`\
#    |
#  --|--
#  / | \
# @  |    @
#    |
#  / | \
#  @   @

# %% [markdown]
# ### Functions: Common errors

# %%
centimeters_per_inch =  2.54
inches_per_foot = 12

def height_US_to_centimeters(feet, inches):
    """ Converts a height in feet/ inches to centimeters."""
    total_inches = (feet * inches_per_foot) + inches # Total inches
    centimeters = total_inches * centimeters_per_inch
    return centimeters

i_feet = int(input('Enter feet: '))
i_inches = int(input( ' Enter inches:'))
print( 'Feet: ' , i_feet)
print( 'Inches: ' , i_inches)

print( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))
# Out:
# Feet:  3
# Inches:  4
# Centimeters:  101.6

# %% [markdown]
# ### Global varibles

# %%
employee_name = 'N/A'
def get_name():

    name = input( ' Enter employee name: ' )
    global employee_name
    employee_name = name
    print( ' Employee name: ' , employee_name)

get_name ( )
print( ' Employee name: ' , employee_name)
# Out:
#  Employee name:  AARTI HADGE
#  Employee name:  AARTI HADGE

# %%
employee_name = 'N/A'
def get_name():
    global employee_name
    name = input('Enter employee name: ')
    employee_name = name
get_name ( )
print( ' Employee name: ' , employee_name)
# Out:
#  Employee name:  Aarti Hadge

# %% [markdown]
# ### Namespaces and scope resolution

# %%
print('Initial global namespace: ')
globals()
# Out:
# Initial global namespace:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n    print( ' Employee name: ' , employee_name)\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee name = 'N/A\ndef get_name():\n    global employee_name\n    name = input( Enter employee name:'')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "print('Initial global namespace: ')\nglobals()"],
#  '_oh': {},
#  '_dh': [PosixPath('/workspaces/VIBE-Coding-with-Python')],
#  'In': ['',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n    print( ' Employee name: ' , employee_name)\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee name = 'N/A\ndef get_name():\n    global employee_name\n    name = input( Enter employee name:'')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "print('Initial global namespace: ')\nglobals()"],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x71d3186f3800>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x71d3181e7770>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x71d3181e7770>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/workspaces/VIBE-Coding-with-Python/06_Functions.ipynb',
#  '_i': "employee name = 'N/A\ndef get_name():\n    global employee_name\n    name = input( Enter employee name:'')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_ii': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n    print( ' Employee name: ' , employee_name)\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_iii': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i1': 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#  'centimeters_per_inch': 2.54,
#  'inches_per_foot': 12,
#  'height_US_to_centimeters': <function __main__.height_US_to_centimeters(feet, inches)>,
#  '_i2': 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#  'i_feet': 3,
#  'i_inches': 4,
#  '_i3': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  'employee_name': 'AARTI HADGE',
#  'get_name': <function __main__.get_name()>,
#  '_i4': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i5': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n    print( ' Employee name: ' , employee_name)\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i6': "employee name = 'N/A\ndef get_name():\n    global employee_name\n    name = input( Enter employee name:'')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i7': "print('Initial global namespace: ')\nglobals()"}

# %%
my_var = "This is a variable"
print("\nCreated new variable")
print(globals())
# Out:
# Created new variable
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))', 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))', "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n    print( ' Employee name: ' , employee_name)\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee name = 'N/A\ndef get_name():\n    global employee_name\n    name = input( Enter employee name:'')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "print('Initial global namespace: ')\nglobals()", 'my_var = "This is a variable"\nprint("\\nCreated new variable")\nprint((globals()))', 'my_var = "This is a variable"\nprint("\\nCreated new variable")\nprint(globals())'], '_oh': {7: {...}}, '_dh': [PosixPath('/workspaces/VIBE-Coding-with-Python')], 'In': ['', 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))', 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))', "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    globa ...

# %%
def my_function():
    pass

print("\nCreated new function")
print(globals())
# Out:
# Created new function
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))', 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))', "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n    print( ' Employee name: ' , employee_name)\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee name = 'N/A\ndef get_name():\n    global employee_name\n    name = input( Enter employee name:'')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "print('Initial global namespace: ')\nglobals()", 'my_var = "This is a variable"\nprint("\\nCreated new variable")\nprint((globals()))', 'my_var = "This is a variable"\nprint("\\nCreated new variable")\nprint(globals())', 'def my_function():\n    pass\n\nprint("\\nCreated new function")\nprint(globals())'], '_oh': {7: {...}}, '_dh': [PosixPath('/workspaces/VIBE-Coding-with-Python')], 'In': ['', 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))', 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))', "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)", "employee_na ...

# %% [markdown]
# #### Scope resolution

# %%
daily_cals = 2300 # Daily calories
soda_cals = 200

def drink_soda(cals_left):
    return cals_left - soda_cals

daily_cals = drink_soda(daily_cals)
print(daily_cals)
# Out:
# 2100

# %% [markdown]
# #### More scoping and namespaces

# %%
def avg(a, b):
    tmp = (a+b)/2.0
    return tmp

a = 5
b = 10
tmp = a + b # Creates tmp in global namespace
print(f'Avg: {avg(a, b): f}' )
print(f' Sum: {tmp:f}')
# Out:
# Avg:  7.500000
#  Sum: 15.000000

# %%
def avg(a, b):
    tmp = (a+b)/2.0     # Creates tmp in Local namespace
    print(locals())
    return tmp
a = 5
b = 10
tmp = a + b # Creates tmp in global namespace

print(f'Avg: {avg(a,b):f}' )
print(f'Sum: {tmp:f}')
globals()
# Out:
# {'a': 5, 'b': 10, 'tmp': 7.5}
# Avg: 7.500000
# Sum: 15.000000
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n    print( ' Employee name: ' , employee_name)\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee name = 'N/A\ndef get_name():\n    global employee_name\n    name = input( Enter employee name:'')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "print('Initial global namespace: ')\nglobals()",
#   'my_var = "This is a variable"\nprint("\\nCreated new variable")\nprint((globals()))',
#   'my_var = "This is a variable"\nprint("\\nCreated new variable")\nprint(globals())',
#   'def my_function():\n    pass\n\nprint("\\nCreated new function")\nprint(globals())',
#   'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\n\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\n\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0     # Creates tmp in Local namespace\n    print(locals())\n    return tmp\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\n\nprint(f'Avg: {avg(a,b):f}' )\nprint(f'Sum: {tmp:f}')\nglobals()"],
#  '_oh': {7: {...}},
#  '_dh': [PosixPath('/workspaces/VIBE-Coding-with-Python')],
#  'In': ['',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n    print( ' Employee name: ' , employee_name)\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee name = 'N/A\ndef get_name():\n    global employee_name\n    name = input( Enter employee name:'')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "print('Initial global namespace: ')\nglobals()",
#   'my_var = "This is a variable"\nprint("\\nCreated new variable")\nprint((globals()))',
#   'my_var = "This is a variable"\nprint("\\nCreated new variable")\nprint(globals())',
#   'def my_function():\n    pass\n\nprint("\\nCreated new function")\nprint(globals())',
#   'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\n\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\n\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0     # Creates tmp in Local namespace\n    print(locals())\n    return tmp\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\n\nprint(f'Avg: {avg(a,b):f}' )\nprint(f'Sum: {tmp:f}')\nglobals()"],
#  'Out': {7: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x71d3186f3800>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x71d3181e7770>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x71d3181e7770>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/workspaces/VIBE-Coding-with-Python/06_Functions.ipynb',
#  '_i': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\n\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_ii': 'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\n\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#  '_iii': 'def my_function():\n    pass\n\nprint("\\nCreated new function")\nprint(globals())',
#  '_i1': 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#  'centimeters_per_inch': 2.54,
#  'inches_per_foot': 12,
#  'height_US_to_centimeters': <function __main__.height_US_to_centimeters(feet, inches)>,
#  '_i2': 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\nprint( \'Feet: \' , i_feet)\nprint( \'Inches: \' , i_inches)\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#  'i_feet': 3,
#  'i_inches': 4,
#  '_i3': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  'employee_name': 'AARTI HADGE',
#  'get_name': <function __main__.get_name()>,
#  '_i4': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i5': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    global employee_name\n    employee_name = name\n    print( ' Employee name: ' , employee_name)\n\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i6': "employee name = 'N/A\ndef get_name():\n    global employee_name\n    name = input( Enter employee name:'')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i7': "print('Initial global namespace: ')\nglobals()",
#  '_7': {...},
#  '_i8': 'my_var = "This is a variable"\nprint("\\nCreated new variable")\nprint((globals()))',
#  'my_var': 'This is a variable',
#  '_i9': 'my_var = "This is a variable"\nprint("\\nCreated new variable")\nprint(globals())',
#  '_i10': 'def my_function():\n    pass\n\nprint("\\nCreated new function")\nprint(globals())',
#  'my_function': <function __main__.my_function()>,
#  '_i11': 'daily_cals = 2300 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\n\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#  'daily_cals': 2100,
#  'soda_cals': 200,
#  'drink_soda': <function __main__.drink_soda(cals_left)>,
#  '_i12': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\n\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  'avg': <function __main__.avg(a, b)>,
#  'a': 5,
#  'b': 10,
#  'tmp': 15,
#  '_i13': "def avg(a, b):\n    tmp = (a+b)/2.0     # Creates tmp in Local namespace\n    print(locals())\n    return tmp\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\n\nprint(f'Avg: {avg(a,b):f}' )\nprint(f'Sum: {tmp:f}')\nglobals()"}

# %%
def birthday(age):
'''Celebrate birthday'''
age = age + 1
return age

timmy_age = 7
print (birthday (timmy_age) )

# %%
def print_date(day, month, year, style=ø) :
if style == 0: # American
  print(month, ' / ',day,'/',year)
elif(style == 1): # European
    print(day, '/' ,month, '/' , year)
else:
print( 'Invalid Code')

# %%
def append_to_list(value, my_list=[]):
my_list. append ( value)
return my _ list

numbers= append_to_list (50)     # default List appended with 50
print(numbers)

# %%
def print _ sandwich (bread, slice, *args):
    print(f'Arbitary arguments are . ' ,
    print(f' {slice} on {bread}' , end='')
    if len(args) > 0:
       print( 'with', end='')
for extra in args:
    print(extra, end='')
print('')

# %%
student_scores = [75, 84, 66, 99, 51, 65]

def get_grade_stats(scores):
    # calculate the arithmetic mean
mean = sum(scores)/len(scores)

# Calculate the standard deviation
tmp = 0
for score in scores:
    tmp += (tmp/len(scores))**2
std_dev = (tmp/1en(scores))**ø.5

# Package and return average, standard deviation in a tuple
return mean, std dev

# Unpack tuple
average, standard_deviation = get_grade_stats(student_scores)

print( 'Average score: ' , average)
print( 'Standard deviation: ' , standard_deviation)
