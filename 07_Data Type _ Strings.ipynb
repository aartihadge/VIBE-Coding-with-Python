# %% [markdown]
# ### String slicing

# %%
url = 'https://www.pythonacademy.in/'
domain = url[8:28]
print(domain)
# Out:
# www.pythonacademy.in

# %%
my_str = 'Aarti'
print(my_str[0:-1])
# Out:
# Aart

# %%
string_var = 'Hey folks'
print (string_var[:5])
# Out:
# Hey f

# %%
print(string_var[5:])
# Out:
# olks

# %%
string_var = 'Hey folks'
print(string_var[1:5])
# Out:
# ey f

# %% [markdown]
# ##### A slice creates a new object

# %%
my_str = "The cat jumped the brown cow"
animal = my_str[4:7]
print(f'The animal is a {animal}')
# Out:
# The animal is a cat

# %%
my_str = "The fox jumped the brown llama"
print(f'The animal is still a {animal}') # animal variable remains unchanged
# Out:
# The animal is still a cat

# %%
my_str = "The cat jumped the brown cow"
my_str = my_str.replace('cat', 'dog') #cat is overwritten with dog
print(my_str)
# Out:
# The dog jumped the brown cow

# %%
my_str = "The cat jumped the brown cow"
my_str_2 = my_str.replace('cat', 'dog') #cat is still in that string, but my_str_2 has the new string with dog means the original string is not changed, but a new string is created with the changes
print(my_str)
print(my_str_2)
# Out:
# The cat jumped the brown cow
# The dog jumped the brown cow

# %% [markdown]
# ##### The slice stride

# %%
my_str = "The fox jumped the brown llama"
print(my_str[0:10:2])
# Out:
# Tefxj

# %%
numbers = '0123456789'
print(numbers[0:10:2]) # prints every second character
# Out:
# 02468

# %%
print(numbers[::]) # all characters are printed
# Out:
# 0123456789

# %%
numbers = '0123456789'
print(numbers[1:10:2]) # prints every second character
# Out:
# 13579

# %% [markdown]
# ### Advanced string formatting

# %%
names = ['Sadio Mane' , 'Gabriel Jesus']
goals = [22, 7]
print(f' {"player Name":<16}{"Goals":<8} ' )      #Replaced in table below
print( '_'* 24)
for i in range(2):
    print(f' {names [i] :<16}{goals[i]:<8}')      #Replaced in table below
#RepLaced in table below
#Replaced in table below
# Out:
#  player Name     Goals
# ________________________
#  Sadio Mane      22
#  Gabriel Jesus   7

# %%
names = ['Sadio Mane' , 'Gabriel Jesus']
goals = [22, 7]
print(f' {"player Name":<16}{"Goals":<8} ' )      #Replaced in table below
print( '_'* 24)
for i in range(2):
    print(f' {names [i] :<16}{goals[i]:*>8}')      #Replaced in table below and with *> the output is right aligned and padded with * to the left
#RepLaced in table below
#Replaced in table below
# Out:
#  player Name     Goals
# ________________________
#  Sadio Mane      ******22
#  Gabriel Jesus   *******7

# %%
import math
real_pi = math. pi # math Library provides close approximation of pi
approximate_pi = 22.0 / 7.0 # Approximately correct pi to within 2 decimal places

print(f'pi is {real_pi}')
print(f'22/7 is {approximate_pi}')
print (f'22/7 looks better like {approximate_pi: .2f}')
# Out:
# pi is 3.141592653589793
# 22/7 is 3.142857142857143
# 22/7 looks better like  3.14

# %% [markdown]
# ### String methods

# %% [markdown]
# ##### replace() string method

# %%
phrase = 'One day I will have three goats, six horses,and nine 11amas.' 
# Replace English with Spanish.

phrase = phrase. replace('one', 'uno')
phrase = phrase. replace ('two', 'dos')
phrase = phrase. replace('three','tres')
phrase = phrase. replace('four','cuatro')
phrase = phrase. replace ('five', 'cinco')
phrase = phrase. replace ('six','seis')
phrase = phrase. replace ('seven','siete')
phrase = phrase. replace('eight', 'ocho')
phrase = phrase. replace( 'nine', 'nueve')

print( 'Translation: ' , phrase)
# Out:
# Translation:  One day I will have tres goats, seis horses,and nueve 11amas.

# %% [markdown]
# ##### Use 'in' to check if a character or substring is contained by another string

# %%
superhero_name = "batman forever"
if 'batman' in superhero_name:
# Statements to execute if superhero_name contains 'batman' in any position.
    print("The superhero name contains 'batman' . ")
else :
    print( "The superhero name does not contain 'batman'.")
# Out:
# The superhero name contains 'batman' .

# %% [markdown]
# ##### String comparison

# %%
student_name = input( 'Enter student name:\n')

if student_name == 'Aarti Hadge':
    print( 'Identity operator: True')
else:
    print( 'Identity operator: False')
# Out:
# Identity operator: True

# %%
student_name = input('Enter student name:\n')

if student_name == 'Aarti Hadge':
   print('Equality operator: True')
else:
    print('Equality operator: False')
# Out:
# Equality operator: False

# %% [markdown]
# ### Splitting and joining strings

# %%
string = 'Music/artist/song.mp3'
my_tokens= string. split('/')
print (my_tokens)
# Out:
# ['Music', 'artist', 'song.mp3']

# %%
string =  'I love python'
my_tokens = string. split()
print (my_tokens)
# Out:
# ['I', 'love', 'python']

# %%
url = input('Enter URL:\n ')
print('URL is: ', url)
tokens = url.split('/') # Uses '/' separator
print (tokens)
# Out:
# URL is:  https://probable-capybara-wrv7475g54qxc5j79.github.dev/
# ['https:', '', 'probable-capybara-wrv7475g54qxc5j79.github.dev', '']

# %%
web_path ='www.website.com' , ' profile', ' settings '
separator = '/'
url= separator. join(web_path)
print(url)
# Out:
# www.website.com/ profile/ settings

# %%
phrases = ['To be, ', 'or not to be.\n', 'That is the question.']

sentence = ''
for phrase in phrases:
    sentence += phrase
print (sentence)
# Out:
# To be, or not to be.
# That is the question.

# %%
path = 'home/user/documents/file.txt'
print('File name is: ', path)

new_separator = input('Enter new separator:\n')
print('New separator is: ', new_separator)
tokens = path.split('/')
print('Tokens are: ', tokens)
print('Joined string is: ', new_separator.join(tokens))
# Out:
# File name is:  home/user/documents/file.txt
# New separator is:  @
# Tokens are:  ['home', 'user', 'documents', 'file.txt']
# Joined string is:  home@user@documents@file.txt
